# %%
import numpy as np
from matplotlib import pyplot as plt

# Generate "real" data
X = np.random.normal(size=(1000, 2))
A1 = np.array([[1, 2], [-0.1, 0.5]])
b1 = np.array([1, 2])
X1 = np.dot(X,A1) + b1
A2 = np.array([[2, 1], [1, -1]])
b2 = np.array([20, 1])
X2 = np.dot(X,A2) + b2
X = 0.5 * (X1 + X2)

# and stick them into an iterator
batch_size = 4

def iterate_minibatch(x, x1, batch_size, shuffle=True):
    indices = np.arange(x.shape[0])
    if shuffle:
        np.random.shuffle(indices)
    
    for i in range(0, x.shape[0], batch_size):
        yield x[indices[i:i+batch_size], :], x1[indices[i:i+batch_size], :]

plt.scatter(X[:, 0], X[:, 1], c='b')
plt.scatter(X1[:, 0], X1[:, 1], c='g')
plt.scatter(X2[:, 0], X2[:, 1], c='r')

plt.show()

# %%
"""
Define the network
reference:
1. https://github.com/zackchase/mxnet-the-straight-dope/blob/master/P10-C01-gan-intro.ipynb
2. https://github.com/carpedm20/DCGAN-tensorflow
"""

import tensorflow as tf

# conditional GAN
class CGAN(object):
    def __init__(self):
        
        # input, output
        self.z = tf.placeholder(tf.float32, shape=[None, 2], name='z')
        self.x = tf.placeholder(tf.float32, shape=[None, 2], name='x')
        self.x1 = tf.placeholder(tf.float32, shape=[None, 2], name='real_x1')
        
        # define the network
        self.fake_x1 = self.netG(self.z, self.x, name='netG1')
        self.real_logits = self.netD(self.x1, self.x, reuse=False)
        self.fake_logits = self.netD(self.fake_x1, self.x, reuse=True)
        
        # define losses
        self.loss_D = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=self.real_logits,
                                                                            labels=tf.ones_like(self.real_logits))) + \
                      tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=self.fake_logits,
                                                                            labels=tf.zeros_like(self.real_logits)))
        self.loss_G = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=self.fake_logits,
                                                                            labels=tf.ones_like(self.real_logits)))
        self.loss_L1 = tf.losses.absolute_difference(self.x1, self.fake_x1) * 100
        
        # collect variables
        t_vars = tf.trainable_variables()
        self.d_vars = [var for var in t_vars if 'd_' in var.name]
        self.g_vars = [var for var in t_vars if 'g_' in var.name]
    
    def netG(self, z, x, name='generator'):
        """1-layer fully connected network"""

        with tf.variable_scope(name) as scope:
            
            W1 = tf.get_variable(name="g_W1", shape=[2, 2],
                                initializer=tf.contrib.layers.xavier_initializer(),
                                trainable=True)
            W2 = tf.get_variable(name="g_W2", shape=[2, 2],
                                initializer=tf.contrib.layers.xavier_initializer(),
                                trainable=True)
            b = tf.get_variable(name="g_b", shape=[2],
                                initializer=tf.zeros_initializer(),
                                trainable=True)
            return tf.matmul(z, W1) + tf.matmul(x,W2) + b
        
    def netD(self, x1, x, reuse=False):
        """3-layer fully connected network"""
        with tf.variable_scope("discriminator") as scope:
            if reuse:
                scope.reuse_variables()
         
            W11 = tf.get_variable(name="d_W11", shape=[2, 6],
                                initializer=tf.contrib.layers.xavier_initializer(),
                                trainable=True)
            W12 = tf.get_variable(name="d_W12", shape=[2, 6],
                                initializer=tf.contrib.layers.xavier_initializer(),
                                trainable=True)
            b1 = tf.get_variable(name="d_b1", shape=[6],
                                initializer=tf.zeros_initializer(),
                                trainable=True)
            W2 = tf.get_variable(name="d_W2", shape=[6, 4],
                                initializer=tf.contrib.layers.xavier_initializer(),
                                trainable=True)
            b2 = tf.get_variable(name="d_b2", shape=[4],
                                initializer=tf.zeros_initializer(),
                                trainable=True)
            W3 = tf.get_variable(name="d_W3", shape=[4, 1],
                                initializer=tf.contrib.layers.xavier_initializer(),
                                trainable=True)
            b3 = tf.get_variable(name="d_b3", shape=[1],
                                initializer=tf.zeros_initializer(),
                                trainable=True)
            
            layer1 = tf.nn.tanh(tf.matmul(x, W12) + tf.matmul(x1, W11) + b1)
            layer2 = tf.nn.tanh(tf.matmul(layer1, W2) + b2)
            return tf.matmul(layer2, W3) + b3

# %%
"""Paired data translation"""

# Training loop
gan = CGAN()
d_optim = tf.train.AdamOptimizer(learning_rate=0.05).minimize(gan.loss_D, var_list=gan.d_vars)
g_optim = tf.train.AdamOptimizer(learning_rate=0.01).minimize(gan.loss_G+gan.loss_L1, var_list=gan.g_vars)

init = tf.global_variables_initializer()

config = tf.ConfigProto(device_count = {'GPU': 0})
with tf.Session(config=config) as sess:
    sess.run(init)
    
    for epoch in range(30):
        avg_loss = 0.
        count = 0
        for x_batch, x1_batch in iterate_minibatch(X, X1, batch_size=batch_size):
            # generate noise z
            z_batch = np.random.normal(size=(4, 2))
            
            # update D network
            loss_D, _, = sess.run([gan.loss_D, d_optim],
                                feed_dict={
                                    gan.z: z_batch,
                                    gan.x: x_batch,
                                    gan.x1: x1_batch,
                                })
            
            # update G network
            loss_G, _ = sess.run([gan.loss_G, g_optim],
                                feed_dict={
                                    gan.z: z_batch,
                                    gan.x: x_batch,
                                    gan.x1: x1_batch,
                                })
            
            avg_loss += loss_D
            count += 1
            
        avg_loss /= count
        z = np.random.normal(size=(100, 2))
        excerpt = np.random.randint(1000, size=100)
        fake_x1, real_logits, fake_logits = sess.run([gan.fake_x1, gan.real_logits, gan.fake_logits],
                         feed_dict={gan.z: z, gan.x: X[excerpt,:], gan.x1: X1[excerpt,:]})
        accuracy = 0.5 * (np.sum(real_logits>0) / 100. + np.sum(fake_logits<0) / 100.)
        print('\ndiscriminator loss at epoch %d: %f' % (epoch, avg_loss))
        print('\ndiscriminator accuracy at epoch %d: %f' % (epoch, accuracy))
        plt.scatter(X[excerpt, 0], X[excerpt, 1], c='b')
        plt.scatter(X1[excerpt, 0], X1[excerpt, 1], c='g')
        plt.scatter(fake_x1[:, 0], fake_x1[:, 1], c='r')
        plt.show()
# Out:
# discriminator loss at epoch 0: 1.070767
#
# discriminator accuracy at epoch 0: 0.630000
# discriminator loss at epoch 1: 1.237056
#
# discriminator accuracy at epoch 1: 0.630000
# discriminator loss at epoch 2: 1.286808
#
# discriminator accuracy at epoch 2: 0.500000
# discriminator loss at epoch 3: 1.280673
#
# discriminator accuracy at epoch 3: 0.625000
# discriminator loss at epoch 4: 1.326194
#
# discriminator accuracy at epoch 4: 0.535000
# discriminator loss at epoch 5: 1.390877
#
# discriminator accuracy at epoch 5: 0.540000
# discriminator loss at epoch 6: 1.293751
#
# discriminator accuracy at epoch 6: 0.610000
# discriminator loss at epoch 7: 1.318738
#
# discriminator accuracy at epoch 7: 0.575000
# discriminator loss at epoch 8: 1.358141
#
# discriminator accuracy at epoch 8: 0.500000
# discriminator loss at epoch 9: 1.328544
#
# discriminator accuracy at epoch 9: 0.500000
# discriminator loss at epoch 10: 1.332697
#
# discriminator accuracy at epoch 10: 0.500000
# discriminator loss at epoch 11: 1.364256
#
# discriminator accuracy at epoch 11: 0.530000
# discriminator loss at epoch 12: 1.368141
#
# discriminator accuracy at epoch 12: 0.540000
# discriminator loss at epoch 13: 1.350432
#
# discriminator accuracy at epoch 13: 0.550000
# discriminator loss at epoch 14: 1.327695
#
# discriminator accuracy at epoch 14: 0.555000
# discriminator loss at epoch 15: 1.347459
#
# discriminator accuracy at epoch 15: 0.590000
# discriminator loss at epoch 16: 1.336563
#
# discriminator accuracy at epoch 16: 0.545000
# discriminator loss at epoch 17: 1.338038
#
# discriminator accuracy at epoch 17: 0.580000
# discriminator loss at epoch 18: 1.362646
#
# discriminator accuracy at epoch 18: 0.515000
# discriminator loss at epoch 19: 1.351907
#
# discriminator accuracy at epoch 19: 0.500000

# %%
"""Unpaired data translation"""

# Training loop
gan = CGAN()
d_optim = tf.train.AdamOptimizer(learning_rate=0.05).minimize(gan.loss_D, var_list=gan.d_vars)
g_optim = tf.train.AdamOptimizer(learning_rate=0.01).minimize(gan.loss_G, var_list=gan.g_vars)

init = tf.global_variables_initializer()

config = tf.ConfigProto(device_count = {'GPU': 0})
with tf.Session(config=config) as sess:
    sess.run(init)
    
    for epoch in range(30):
        avg_loss = 0.
        count = 0
        for x_batch, _ in iterate_minibatch(X, X1, batch_size=batch_size):
            # generate noise z
            z_batch = np.random.normal(size=(4, 2))
            excerpt = np.random.randint(1000, size=4)
            x1_batch = X1[excerpt, :]    # unpaired data
            
            # update D network
            loss_D, _, = sess.run([gan.loss_D, d_optim],
                                feed_dict={
                                    gan.z: z_batch,
                                    gan.x: x_batch,
                                    gan.x1: x1_batch,
                                })
            
            # update G network
            loss_G, _ = sess.run([gan.loss_G, g_optim],
                                feed_dict={
                                    gan.z: z_batch,
                                    gan.x: x_batch,
                                    gan.x1: x1_batch,
                                })
            
            avg_loss += loss_D
            count += 1
            
        avg_loss /= count
        z = np.random.normal(size=(100, 2))
        excerpt = np.random.randint(1000, size=100)
        fake_x1, real_logits, fake_logits = sess.run([gan.fake_x1, gan.real_logits, gan.fake_logits],
                         feed_dict={gan.z: z, gan.x: X[excerpt,:], gan.x1: X1[excerpt,:]})
        accuracy = 0.5 * (np.sum(real_logits>0) / 100. + np.sum(fake_logits<0) / 100.)
        print('\ndiscriminator loss at epoch %d: %f' % (epoch, avg_loss))
        print('\ndiscriminator accuracy at epoch %d: %f' % (epoch, accuracy))
        plt.scatter(X[excerpt, 0], X[excerpt, 1], c='b')
        plt.scatter(X1[excerpt, 0], X1[excerpt, 1], c='g')
        plt.scatter(fake_x1[:, 0], fake_x1[:, 1], c='r')
        plt.show()
